# %%
def read_input(filename):
    with open(filename) as f:
        lines = f.readlines()

#     array = []

#     for line in lines:
#         line = line.rstrip()
#         array.append(line)

#     return array

    return lines[0]

print(read_input('day_6_sample_input_0'))
print(read_input('day_6_sample_input_1'))
print(read_input('day_6_sample_input_2'))
print(read_input('day_6_sample_input_3'))
# print(read_input('day_6_input'))
# Out:
# bvwbjplbgvbhsrlpgdmjqwftvncz
# nppdvjthqldpwncqszvftbrmjlhg
# nznrnfrfntjfmvfwmzdfjlvtqnbhcprsg
# zcfzfwzzqfrljwzlrfnpqdbhtmscgvjw

# %%
def find_index(filename): #for part 1 - 4 unique characters
    letters = read_input(filename)
    
    i = 3
    while i < len(letters):
        four_letters = [letters[i], letters[i-1], letters[i-2], letters[i-3]]
#         print(four_letters)
        unique_letters = set(four_letters)
        
        if len(unique_letters) == 4:
            return i+1
        
        i+=1
    
print(find_index('day_6_sample_input_0'))
print(find_index('day_6_sample_input_1'))
print(find_index('day_6_sample_input_2'))
print(find_index('day_6_sample_input_3'))
print(find_index('day_6_input'))
# Out:
# 5
# 6
# 10
# 11
# 1647

# %%
def find_index_19(filename): #for part 2 - 14 unique characters
    letters = read_input(filename)
    
    i = 15
    while i < len(letters):

        #         idk what's wrong here and idc
#         four_letters = [] #four_letters will no longer be for four letters
#         number = 14
#         while number > 0:
#             four_letters.insert(0, letters[number - 1])
#             number -= 1
        four_letters = [letters[i], letters[i-1], letters[i-2], letters[i-3], letters[i-4], letters[i-5], letters[i-6], letters[i-7], letters[i-8], letters[i-9], letters[i-10], letters[i-11], letters[i-12], letters[i-13]]
        
        print(four_letters)
        unique_letters = set(four_letters)
        print(unique_letters)

        if len(unique_letters) == 14:
            return i+1
        else:
            i+=1
#             print(i)
    
print(find_index_19('day_6_sample_input_0'))
# print(find_index_19('day_6_sample_input_1'))
# print(find_index_19('day_6_sample_input_2'))
# print(find_index_19('day_6_sample_input_3'))
print(find_index_19('day_6_input'))
# Out:
# ['p', 'l', 'r', 's', 'h', 'b', 'v', 'g', 'b', 'l', 'p', 'j', 'b', 'w']
# {'h', 'r', 's', 'v', 'g', 'b', 'j', 'l', 'p', 'w'}
# ['g', 'p', 'l', 'r', 's', 'h', 'b', 'v', 'g', 'b', 'l', 'p', 'j', 'b']
# {'h', 'r', 'g', 's', 'v', 'b', 'j', 'l', 'p'}
# ['d', 'g', 'p', 'l', 'r', 's', 'h', 'b', 'v', 'g', 'b', 'l', 'p', 'j']
# {'h', 'r', 'g', 's', 'd', 'b', 'v', 'j', 'l', 'p'}
# ['m', 'd', 'g', 'p', 'l', 'r', 's', 'h', 'b', 'v', 'g', 'b', 'l', 'p']
# {'h', 'r', 'g', 's', 'd', 'b', 'v', 'l', 'p', 'm'}
# ['j', 'm', 'd', 'g', 'p', 'l', 'r', 's', 'h', 'b', 'v', 'g', 'b', 'l']
# {'h', 'r', 'g', 's', 'd', 'b', 'v', 'j', 'l', 'p', 'm'}
# ['q', 'j', 'm', 'd', 'g', 'p', 'l', 'r', 's', 'h', 'b', 'v', 'g', 'b']
# {'q', 'h', 'r', 'g', 's', 'd', 'b', 'v', 'j', 'l', 'p', 'm'}
# ['w', 'q', 'j', 'm', 'd', 'g', 'p', 'l', 'r', 's', 'h', 'b', 'v', 'g']
# {'q', 'h', 'r', 'g', 's', 'd', 'b', 'v', 'j', 'l', 'p', 'w', 'm'}
# ['f', 'w', 'q', 'j', 'm', 'd', 'g', 'p', 'l', 'r', 's', 'h', 'b', 'v']
# ...
