# %%
def read_input(filename):
    with open(filename) as f:
        lines = f.readlines()

    array = []

    for line in lines:
        line = line.rstrip()
        print(line)
        array.append(line)

    return array

print(read_input('day_2_sample_input'))
# Out:
# A Y
# B X
# C Z
# ['A Y', 'B X', 'C Z']

# %%
def tally_score(input_file):
    input_array = read_input(input_file)
    your_score = 0
    their_score = 0
    
    for line in input_array:
        round_result = line.split(' ')
        print(round_result)
        
        their_choice = round_result[0]
        your_choice = round_result[1]
        
        match your_choice:
            case 'X': #rock
                your_score = your_score + 1
                match their_choice:
                    case 'A': #rock
                        their_score = their_score + 1
                        your_score = your_score + 3
                        their_score = their_score + 3 #writing it this way for clarity
                    case 'B': #paper
                        their_score = their_score + 2
                        #your_score = your_score + 0 #for clarity
                        their_score = their_score + 6
                    case 'C': #scissors
                        their_score = their_score + 3
                        your_score = your_score + 6
                        #their_score = their_score + 0
            case 'Y': #paper
                your_score = your_score + 2
                match their_choice:
                    case 'A': #rock
                        their_score = their_score + 1
                        your_score = your_score + 6
                        #their_score = their_score + 0
                    case 'B': #paper
                        their_score = their_score + 2
                        your_score = your_score + 3
                        their_score = their_score + 3
                    case 'C': #scissors
                        their_score = their_score + 3
                        #your_score = your_score + 0
                        their_score = their_score + 6
            case 'Z': #scissors
                your_score = your_score + 3
                match their_choice:
                    case 'A': #rock
                        their_score = their_score + 1
                        #your_score = your_score + 0
                        their_score = their_score + 6
                    case 'B': #paper
                        their_score = their_score + 2
                        your_score = your_score + 6
                        #their_score = their_score + 0
                    case 'C': #scissors
                        their_score = their_score + 3
                        your_score = your_score + 3
                        their_score = their_score + 3
                        
    print(your_score)
    print(their_score)
        
tally_score('day_2_sample_input')
# Out:
#   File "<ipython-input-10-dc5907819299>", line 13
#     match your_choice:
#           ^
# SyntaxError: invalid syntax

# %%
import sys;print(sys.version)
# Out:
# 3.8.5 (default, Sep  4 2020, 02:22:02)
# [Clang 10.0.0 ]

# %%
def tally_score(input_file):
    input_array = read_input(input_file)
    your_score = 0
    their_score = 0
    
    for line in input_array:
        round_result = line.split(' ')
        print(round_result)
        
        their_choice = round_result[0]
        your_choice = round_result[1]
        
        if your_choice == 'X': #rock
            your_score = your_score + 1
            if their_choice == 'A': #rock
                their_score = their_score + 1
                your_score = your_score + 3
                their_score = their_score + 3 #writing it this way for clarity
            elif their_choice == 'B': #paper
                their_score = their_score + 2
                #your_score = your_score + 0 #for clarity
                their_score = their_score + 6
            elif their_choice == 'C': #scissors
                their_score = their_score + 3
                your_score = your_score + 6
                #their_score = their_score + 0
        elif your_choice == 'Y': #paper
            your_score = your_score + 2
            if their_choice == 'A': #rock
                their_score = their_score + 1
                your_score = your_score + 6
                #their_score = their_score + 0
            elif their_choice == 'B': #paper
                their_score = their_score + 2
                your_score = your_score + 3
                their_score = their_score + 3
            elif their_choice == 'C': #scissors
                their_score = their_score + 3
                #your_score = your_score + 0
                their_score = their_score + 6
        elif your_choice == 'Z': #scissors
            your_score = your_score + 3
            if their_choice == 'A': #rock
                their_score = their_score + 1
                #your_score = your_score + 0
                their_score = their_score + 6
            elif their_choice == 'B': #paper
                their_score = their_score + 2
                your_score = your_score + 6
                #their_score = their_score + 0
            elif their_choice == 'C': #scissors
                their_score = their_score + 3
                your_score = your_score + 3
                their_score = their_score + 3
                        
    print(your_score)
    print(their_score)
        
tally_score('day_2_sample_input')
# Out:
# A Y
# B X
# C Z
# ['A', 'Y']
# ['B', 'X']
# ['C', 'Z']
# 15
# 15

# %%
tally_score('day_2_input')
# Out:
# C X
# B Y
# C Z
# C Z
# B X
# C Z
# C Z
# C Z
# B X
# B Y
# B Z
# B Z
# B Z
# C X
# C Y
# B Y
# C Z
# C Y
# C X
# B Y
# C Y
# C Z
# A Y
# B Y
# C X
# C X
# C Y
# B Y
# B X
# C Z
# B Y
# B Z
# C Y
# A X
# B Y
# B X
# B Y
# B X
# C Z
# B Y
# C Y
# A Z
# B Y
# C Z
# A Z
# B Y
# B Y
# B Y
# C Y
# B Y
# A X
# C Z
# C X
# C Z
# A Y
# C X
# C Z
# C Y
# C Y
# A Y
# C Z
# B Y
# B Z
# A X
# C Z
# B Y
# C X
# B X
# C Z
# C Z
# B Y
# C Z
# A Z
# C X
# C Y
# B X
# C X
# C Z
# B Z
# B Z
# B Z
# B Y
# A X
# B Y
# C Y
# B Z
# B Y
# C Y
# C X
# B Z
# C X
# B Y
# A Y
# B X
# C Z
# A Z
# C Y
# C Y
# A Z
# B Z
# B Z
# C Z
# B X
# B X
# C Y
# C Z
# B X
# B X
# A Z
# C X
# C Z
# A Y
# B Z
# B Y
# B Y
# C Z
# C X
# B Z
# A X
# B Y
# B Z
# B Z
# A Z
# A Y
# B X
# B Y
# A X
# C Y
# B Y
# B Y
# B Y
# B Y
# B X
# C Z
# C Z
# C Z
# C Z
# B Z
# C Z
# A X
# C Z
# C X
# B Z
# C X
# A Z
# A Y
# B Z
# A Y
# A X
# B Y
# A Z
# C Z
# C Z
# B X
# C Z
# A Y
# C Z
# B Y
# C Z
# C X
# A Z
# B Y
# B Y
# C X
# A Z
# C Z
# ...

# %% [markdown]
# your score: 13221
# their score: 12734
